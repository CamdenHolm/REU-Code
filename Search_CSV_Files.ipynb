# %%
import re

with open('2018-12-14-device-510k-0001-of-0001.csv', 'r') as f2:    
    text = f2.read() 
    
    with open('keywords.csv', 'r') as f:
        keywords = f.read()

results = re.findall('Tissue| graft| graf| matrix| scaffold| filler| void filler| cement| electrosp| weave| woven| non-woven| nonwoven| mesh| ECM| extracellular| acellular| decellularized| recellularized|re-cellularized| seeded| resorbable | absorbable | resorb| sorb| degrad| biodegrad| membrane| tissue| growth factor| tgf-b |tissue growth factor-b | vegf | vascular endothelial growth factor-1| construct| fiber| infiltrat| pore| porous| proliferat| ingrowth| ongrowth| vasculariz| induct |inductive | induction| conduct | conductive|conduction| stimulat| replace| transform| cultured| fixation| morphogenic| BMP-1| IL-4| IL-13| angiopoietin-1 | ANG-1| metallopeptidase-8| metallopeptidase | MMP-8| viscoelastic| inelastic| lattice| differentiation| additive| bioglass| osteo| chondro| filament| penetration| silk| deposition| colonization', text) text) 


print(results)
# Out:
# ['Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' osteo', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' mesh', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' fixation', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' ECM', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' conductive', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' osteo', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' ECM', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' absorbable ', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' ECM', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', ' osteo', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'Tissue', 'T ...
